# %% [markdown]
# # Project 2: Postgres + Pandas for Data Management and Analysis
#
# ### Group Members: Pinxue Lin, Siddanta K C, Aayush Bhetuwal

# %% [markdown]
# ## 1. Introduction
#
#
# We are dealing with data set of Educational attainment for the U.S., States, and counties, from 1970-2020. Since all three of us came to USA from our home country for our higher education, we are interested in knowing about educational achievement of people with less than high school/diploma,only highschool degree/diploma, people with 4 years degree and some college or associate degree etc. From this data set, we can analyze the development trend of the educated population in the United States and the comparison between states and also can compare the states with the highest education levels in different years.

# %% [markdown]
# ### 2. Data Summary

# %% [markdown]
# We used the Educational Attainment data set for the United States, States, and counties from the website "Economic Research Service of US Department of Agriculture." The URL to it is right here. https://www.ers.usda.gov/data-products/county-level-data-sets/download-data/. We have uploaded the data as a csv file into the github and obtained the data using pandas module.
#
# Based on their relationships, we have created various tables. Firstly, State table is created. Then different education level tables were created which stores educated population for different years.
#
# state_information(State* varchar,name varchar)
#
# less_than_highschool("State" varchar[2] PRIMARY KEY, "1970" float, "1980" float, "1990" float, "2000" float, "2007_11" float, "2016_20" float)
#
# highschool_only("State" varchar[2] PRIMARY KEY, "1970" float, "1980" float, "1990" float, "2000" float, "2007_11" float, "2016_20" float)
#
# less_than_4years_college("State" varchar[2] PRIMARY KEY, "1970" float, "1980" float, "1990" float, "2000" float, "2007_11" float, "2016_20" float)
#
# fouryears_college_or_higher("State" varchar[2] PRIMARY KEY, "1970" float, "1980" float, "1990" float, "2000" float, "2007_11" float, "2016_20" float)
#
# total_educated_population("State" varchar[2] PRIMARY KEY, "1970" float, "1980" float, "1990" float, "2000" float, "2007_11" float, "2016_20" float)

# %%
import pandas as pd
f = pd.read_csv('https://raw.githubusercontent.com/azsxscdvfb/AIM-5001/main/week7/Education.csv', skiprows=4, index_col=['State', 'Area name'],thousands=',')
f
# Out:
#                            Federal Information Processing Standards (FIPS) Code  \
# State Area name
# US    United States                                                        0
# AL    Alabama                                                           1000
#       Autauga County                                                    1001
#       Baldwin County                                                    1003
#       Barbour County                                                    1005
# ...                                                                      ...
# PR    Vega Baja Municipio                                              72145
#       Vieques Municipio                                                72147
#       Villalba Municipio                                               72149
#       Yabucoa Municipio                                                72151
#       Yauco Municipio                                                  72153
#
# ...

# %% [markdown]
# ### Part 3: Data Management using PostgreSQL (30 Points)

# %% [markdown]
# #### 3. Formulate SQL statements that will create your proposed database and tables within PostgreSQL, including any required primary and foreign keys.

# %% [markdown]
# CREATE TABLE "state_information" (
#   "State" varchar[2] PRIMARY KEY,
#   "name" varchar[20]
# );
#
# CREATE TABLE "less_than_highschool" (
#   "State" varchar[2] PRIMARY KEY,
#   "1970" float,
#   "1980" float,
#   "1990" float,
#   "2000" float,
#   "2007_11" float,
#   "2016_20" float
# );
#
# CREATE TABLE "highschool_only" (
#   "State" varchar[2] PRIMARY KEY,
#   "1970" float,
#   "1980" float,
#   "1990" float,
#   "2000" float,
#   "2007_11" float,
#   "2016_20" float
# );
#
# CREATE TABLE "less_than_4years_college" (
#   "State" varchar[2] PRIMARY KEY,
#   "1970" float,
#   "1980" float,
#   "1990" float,
#   "2000" float,
#   "2007_11" float,
#   "2016_20" float
# );
#
# CREATE TABLE "fouryears_college_or_higher" (
#   "State" varchar[2] PRIMARY KEY,
#   "1970" float,
#   "1980" float,
#   "1990" float,
#   "2000" float,
#   "2007_11" float,
#   "2016_20" float
# );
#
# CREATE TABLE "total_educated_population" (
#   "State" varchar[2] PRIMARY KEY,
#   "1970" int,
#   "1980" int,
#   "1990" int,
#   "2000" int,
#   "2007_11" int,
#   "2016_20" int
# );
#
# ALTER TABLE "state_information" ADD FOREIGN KEY ("State") REFERENCES "fouryears_college_or_higher" ("State") ON DELETE NO ACTION ON UPDATE NO ACTION;
#
# ALTER TABLE "state_information" ADD FOREIGN KEY ("State") REFERENCES "less_than_4years_college" ("State") ON DELETE NO ACTION ON UPDATE NO ACTION;
#
# ALTER TABLE "state_information" ADD FOREIGN KEY ("State") REFERENCES "less_than_highschool" ("State") ON DELETE NO ACTION ON UPDATE NO ACTION;
#
# ALTER TABLE "state_information" ADD FOREIGN KEY ("State") REFERENCES "highschool_only" ("State") ON DELETE NO ACTION ON UPDATE NO ACTION;
#
# ALTER TABLE "state_information" ADD FOREIGN KEY ("State") REFERENCES "total_educated_population" ("State") ON DELETE NO ACTION ON UPDATE NO ACTION;

# %% [markdown]
# #### 5. Connect to your PostgreSQL server from within your Jupyter Notebook environment and use your knowledge of Python, Pandas, and SQL to load your data set into your new PostgreSQL database. Be sure to include a query that verifies the successful execution of your SQL statements.

# %%
from sqlalchemy import create_engine
import pandas as pd
import numpy as np
import psycopg2
f = pd.read_csv('https://raw.githubusercontent.com/azsxscdvfb/AIM-5001/main/week7/Education.csv', skiprows=4, index_col=['State', 'Area name'],thousands=',')
f

indices = list(range(9,50,8))
less_than_highSchool = f.iloc[:,indices]
indices = list(range(10,51,8))
highSchool_only = f.iloc[:,indices]
indices = list(range(11,52,8))
less_than_4years_college = f.iloc[:, indices]
indices = list(range(12,53,8))
fourYears_college_or_higher = f.iloc[:, indices]

def Sum_series(dfs,arg,n):
    """
    this function is used to obtain the total number of educated population for each year and each state. And also, the whole 
    educated population of the United States.
    """
    sum = 0
    for i in range(arg,arg+n):
        if(pd.isna(dfs[i])):
            return None
        sum +=int(dfs[i])
    return sum
temp = f.index[0][0]
states = [temp]
for i in f.index:
    if(i[0] != temp):
        temp = i[0]
        states.append(temp)
print(states)
state_total_educated_population = pd.DataFrame(columns = ['State','name','1970','1980','1990','2000','2007-11','2016-20'])
for p in states:
    for idx,row in f.iterrows():
        if(idx[0] == p):
            temp_series = pd.Series([idx[0],idx[1],Sum_series(row,5,4),Sum_series(row,13,4),Sum_series(row,21,4),Sum_series(row,29,4),Sum_series(row,37,4),Sum_series(row,45,4)],
                                    index = ['State','name','1970','1980','1990','2000','2007-11','2016-20'])
            state_total_educated_population.loc[len(state_total_educated_population)] = temp_series
            break
state_total_educated_population

def return_state_data(df):
    """
    this function is used to obtain the percentage of educated population of certain education level for states and years.
    It requires education level as an input.
    """
    r_df = pd.DataFrame(columns = ['State','name','1970','1980','1990','2000','2007-11','2016-20'])
    for p in states:
        for idx,row in df.iterrows():
            if(idx[0] == p):
                State_Series = pd.Series({'State' : idx[0],'name': idx[1]})
                row.index = ['1970','1980','1990','2000','2007-11','2016-20']
                row = pd.concat([State_Series,row])
                r_df.loc[len(r_df)] = row
                break
    return r_df

state_less_than_highSchool = return_state_data(less_than_highSchool)
state_highSchool_only = return_state_data(highSchool_only)
state_less_than_4years_college = return_state_data(less_than_4years_college)
state_fourYears_college_or_higher = return_state_data(fourYears_college_or_higher)
# Out:
# ['US', 'AL', 'AK', 'AZ', 'AR', 'CA', 'CO', 'CT', 'DE', 'DC', 'FL', 'GA', 'HI', 'ID', 'IL', 'IN', 'IA', 'KS', 'KY', 'LA', 'ME', 'MD', 'MA', 'MI', 'MN', 'MS', 'MO', 'MT', 'NE', 'NV', 'NH', 'NJ', 'NM', 'NY', 'NC', 'ND', 'OH', 'OK', 'OR', 'PA', 'RI', 'SC', 'SD', 'TN', 'TX', 'UT', 'VT', 'VA', 'WA', 'WV', 'WI', 'WY', 'PR']

# %%
conn_string = 'postgresql://postgres:603068653@localhost:5432/us1'

conn = psycopg2.connect(conn_string)

conn.autocommit = True

cursor = conn.cursor()
cur = conn.cursor()
for idx,row in state_less_than_highSchool.iterrows():
    temp = list(row[0])
    cur.execute("INSERT INTO less_than_highschool  VALUES (%s, %s, %s, %s, %s, %s, %s)", (temp, row[2], row[3], row[4], row[5], row[6], row[7]))
conn.commit()

conn.close()
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# Input In [59], in <cell line: 3>()
#       1 conn_string = 'postgresql://postgres:603068653@localhost:5432/us1'
# ----> 3 conn = psycopg2.connect(conn_string)
#       5 conn.autocommit = True
#       7 cursor = conn.cursor()
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/psycopg2/__init__.py:122, in connect(dsn, connection_factory, cursor_factory, **kwargs)
#     119     kwasync['async_'] = kwargs.pop('async_')
#     121 dsn = _ext.make_dsn(dsn, **kwargs)
# --> 122 conn = _connect(dsn, connection_factory=connection_factory, **kwasync)
#     123 if cursor_factory is not None:
#     124     conn.cursor_factory = cursor_factory
#
# OperationalError: connection to server at "localhost" (::1), port 5432 failed: FATAL:  password authentication failed for user "postgres"

# %%
conn_string = 'postgresql://postgres:603068653@localhost:5432/us1'

conn = psycopg2.connect(conn_string)

conn.autocommit = True

cursor = conn.cursor()
cur = conn.cursor()
sql1 = '''select * from less_than_highschool;'''
cursor.execute(sql1)
for i in cursor.fetchall():
    print(i)

# %%
conn_string = 'postgresql://postgres:603068653@localhost:5432/us1'

conn = psycopg2.connect(conn_string)

conn.autocommit = True

cursor = conn.cursor()
cur = conn.cursor()
for idx,row in state_highSchool_only.iterrows():
    temp = list(row[0])
    cur.execute("INSERT INTO highschool_only  VALUES (%s, %s, %s, %s, %s, %s, %s)", (temp, row[2], row[3], row[4], row[5], row[6], row[7]))
conn.commit()
conn.close()

# %%
conn_string = 'postgresql://postgres:603068653@localhost:5432/us1'

conn = psycopg2.connect(conn_string)

conn.autocommit = True

cursor = conn.cursor()
cur = conn.cursor()
for idx,row in state_less_than_4years_college.iterrows():
    temp = list(row[0])
    cur.execute("INSERT INTO less_than_4years_college  VALUES (%s, %s, %s, %s, %s, %s, %s)", (temp, row[2], row[3], row[4], row[5], row[6], row[7]))
conn.commit()
conn.close()

# %%
conn_string = 'postgresql://postgres:603068653@localhost:5432/us1'

conn = psycopg2.connect(conn_string)

conn.autocommit = True

cursor = conn.cursor()
cur = conn.cursor()
for idx,row in state_fourYears_college_or_higher.iterrows():
    temp = list(row[0])
    cur.execute("INSERT INTO fouryears_college_or_higher  VALUES (%s, %s, %s, %s, %s, %s, %s)", (temp, row[2], row[3], row[4], row[5], row[6], row[7]))
conn.commit()
conn.close()

# %%
conn_string = 'postgresql://postgres:603068653@localhost:5432/us1'

conn = psycopg2.connect(conn_string)

conn.autocommit = True

cursor = conn.cursor()
cur = conn.cursor()
for idx,row in state_total_educated_population.iterrows():
    temp = list(row[0])
    cur.execute("INSERT INTO total_educated_population  VALUES (%s, %s, %s, %s, %s, %s, %s)", (temp, row[2], row[3], row[4], row[5], row[6], row[7]))
conn.commit()
conn.close()

# %%
conn_string = 'postgresql://postgres:603068653@localhost:5432/us1'

conn = psycopg2.connect(conn_string)

conn.autocommit = True

cursor = conn.cursor()
cur = conn.cursor()
for idx,row in state_total_educated_population.iterrows():
    temp1 = list(row[0])
    temp2 = list(row[1])
    cur.execute("INSERT INTO state_information  VALUES (%s, %s)", (temp1,temp2))
conn.commit()
conn.close()

# %%
indices = list(range(9,50,8))
less_than_highSchool = f.iloc[:,indices]
less_than_highSchool
# Out:
#                            Percent of adults with less than a high school diploma, 1970  \
# State Area name
# US    United States                                                     47.7
# AL    Alabama                                                           58.7
#       Autauga County                                                    54.8
#       Baldwin County                                                    59.4
#       Barbour County                                                    68.8
# ...                                                                      ...
# PR    Vega Baja Municipio                                                NaN
#       Vieques Municipio                                                  NaN
#       Villalba Municipio                                                 NaN
#       Yabucoa Municipio                                                  NaN
#       Yauco Municipio                                                    NaN
#
# ...

# %%
indices = list(range(10,51,8))
highSchool_only = f.iloc[:,indices]
highSchool_only
# Out:
#                            Percent of adults with a high school diploma only, 1970  \
# State Area name
# US    United States                                                     31.1
# AL    Alabama                                                           25.9
#       Autauga County                                                    31.1
#       Baldwin County                                                    26.7
#       Barbour County                                                    19.0
# ...                                                                      ...
# PR    Vega Baja Municipio                                                NaN
#       Vieques Municipio                                                  NaN
#       Villalba Municipio                                                 NaN
#       Yabucoa Municipio                                                  NaN
#       Yauco Municipio                                                    NaN
#
# ...

# %%
indices = list(range(11,52,8))
less_than_4years_college = f.iloc[:, indices]
less_than_4years_college
# Out:
#                            Percent of adults completing some college (1-3 years), 1970  \
# State Area name
# US    United States                                                     10.6
# AL    Alabama                                                            7.5
#       Autauga County                                                     7.7
#       Baldwin County                                                     7.4
#       Barbour County                                                     4.9
# ...                                                                      ...
# PR    Vega Baja Municipio                                                NaN
#       Vieques Municipio                                                  NaN
#       Villalba Municipio                                                 NaN
#       Yabucoa Municipio                                                  NaN
#       Yauco Municipio                                                    NaN
#
# ...

# %%
indices = list(range(12,53,8))
fourYears_college_or_higher = f.iloc[:, indices]
fourYears_college_or_higher
# Out:
#                            Percent of adults completing four years of college or higher, 1970  \
# State Area name
# US    United States                                                     10.7
# AL    Alabama                                                            7.8
#       Autauga County                                                     6.4
#       Baldwin County                                                     6.5
#       Barbour County                                                     7.3
# ...                                                                      ...
# PR    Vega Baja Municipio                                                NaN
#       Vieques Municipio                                                  NaN
#       Villalba Municipio                                                 NaN
#       Yabucoa Municipio                                                  NaN
#       Yauco Municipio                                                    NaN
#
# ...

# %%
for idx,row in f.iterrows():
    print(row)
    break
# Out:
# Federal Information Processing Standards (FIPS) Code                                0.0
# 2003 Rural-Uban Continuum Code                                                      NaN
# 2003 Urban Influence Code                                                           NaN
# 2013 Rural-Urban Continuum Code                                                     NaN
# 2013 Urban Influence Code                                                           NaN
# Less than a high school diploma, 1970                                        52373312.0
# High school diploma only, 1970                                               34158051.0
# Some college (1-3 years), 1970                                               11650730.0
# Four years of college or higher, 1970                                        11717266.0
# Percent of adults with less than a high school diploma, 1970                       47.7
# Percent of adults with a high school diploma only, 1970                            31.1
# ...

# %%
#Accessing State Code from the dataSet.
temp = f.index[0][0]
states = [temp]
for i in f.index:
    if(i[0] != temp):
        temp = i[0]
        states.append(temp)
print(states)
# Out:
# ['US', 'AL', 'AK', 'AZ', 'AR', 'CA', 'CO', 'CT', 'DE', 'DC', 'FL', 'GA', 'HI', 'ID', 'IL', 'IN', 'IA', 'KS', 'KY', 'LA', 'ME', 'MD', 'MA', 'MI', 'MN', 'MS', 'MO', 'MT', 'NE', 'NV', 'NH', 'NJ', 'NM', 'NY', 'NC', 'ND', 'OH', 'OK', 'OR', 'PA', 'RI', 'SC', 'SD', 'TN', 'TX', 'UT', 'VT', 'VA', 'WA', 'WV', 'WI', 'WY', 'PR']

# %% [markdown]
# ### Part 4: Exploratory Data Analysis (EDA)

# %%
def return_us_status(df):
    r_df = df.iloc[0]
    r_df.index = ['1970','1980','1990','2000','2007-11','2016-20']
    return r_df

# %% [markdown]
# We have drawn a bar plot to visualize the increased trend in less than high school degree education level from 1970-2020. We can observe from the plot that the increase in the population education attainment for each state is gradual over the years for less than high school degree. State with highest education attainment of less than highschool is SC and lowest is PR.

# %%
import matplotlib.pyplot as plt
US_less_than_high_school = return_us_status(less_than_highSchool)
US_highSchool_only = return_us_status(highSchool_only)
US_less_than_4years_college = return_us_status(less_than_4years_college)
US_fourYears_college_or_higher = return_us_status(fourYears_college_or_higher)

US_less_than_high_school.plot(figsize = (16, 12), label="less_than_high_school")
US_highSchool_only.plot(label = "highSchool_only")
US_less_than_4years_college.plot(label = "less_than_4years_college")
US_fourYears_college_or_higher.plot(label = "fourYears_college_or_higher")
plt.legend(loc = 'upper right')
plt.show()
plt.clf()

# %%
state_less_than_highSchool_increase_between_1970_2020 = pd.DataFrame(state_less_than_highSchool,columns=['State','2016-20'])
for idx,row in state_less_than_highSchool.iterrows():
    state_less_than_highSchool_increase_between_1970_2020.iloc[idx,1] -= row[2]
state_less_than_highSchool_increase_between_1970_2020.set_index('State')
state_less_than_highSchool_increase_between_1970_2020.sort_values('2016-20',inplace=True)
state_less_than_highSchool_increase_between_1970_2020#.reset_index(inplace=True)
plt.figure(figsize=(30, 20), dpi=180)
state_less_than_highSchool_increase_between_1970_2020.plot(figsize = (30,20), kind = "bar", x = 'State',width=0.5)
plt.xticks(fontsize=30)
plt.show()
plt.clf()

# %% [markdown]
# We have drawn a bar plot to visualize the increased trend in four year college or higher degree education level from 1970-2020. We can see from the bar plot that the increase in education attainment for each state is not much for different eras except of DC which is the highest and the lowest state is WV.

# %%
state_fourYears_college_or_higher_increase_between_1970_2020 = pd.DataFrame(state_fourYears_college_or_higher,columns=['State','2016-20'])
for idx,row in state_fourYears_college_or_higher.iterrows():
    state_fourYears_college_or_higher_increase_between_1970_2020.iloc[idx,1] -= row[2]
state_fourYears_college_or_higher_increase_between_1970_2020.set_index('State')
state_fourYears_college_or_higher_increase_between_1970_2020.sort_values('2016-20',inplace=True)
state_fourYears_college_or_higher_increase_between_1970_2020#.reset_index(inplace=True)
state_fourYears_college_or_higher_increase_between_1970_2020.plot(figsize = (30,20), kind = "bar", x = 'State',width=0.5)
plt.xticks(fontsize=30)
plt.show()
plt.clf()

# %% [markdown]
# ### Part 5: Inference

# %% [markdown]
# As our research interest is on developing trends in educated population in the different states of the United States, we have seen that over the years number of people are increasing in pursuing

# %% [markdown]
# ### Part 6: Conclusion

# %% [markdown]
# By answering the research question and exploring various type of education attainment data, in my opinion, the research questions provides the insight on how the education attainment status of US Population at different eras have increased. Based on the data available above, we can conclude that the education attainment in different eras had gradually increased over the course of time. We can conclude that the rise in education attainment level and the interest of the population to seek higher education degrees have increased in different eras and in different States of the United States.
